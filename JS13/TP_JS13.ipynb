# %% [markdown]
# # Tugas: Neural Network dengan Dataset MNIST

# %% [markdown]
# ## Model Dasar: 2 Hidden Layers (128 dan 64 neuron)

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical
import time

# 1. Load dataset MNIST
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Normalisasi data (0-255 → 0-1)
X_train = X_train / 255.0
X_test = X_test / 255.0

# One-hot encoding label
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# 2. Bangun model JST
model = Sequential([
    Flatten(input_shape=(28, 28)),  # Ubah gambar 28x28 menjadi vektor
    Dense(128, activation='relu'),   # Hidden layer 1
    Dense(64, activation='relu'),    # Hidden layer 2
    Dense(10, activation='softmax')  # Output layer (10 kelas)
])

# 3. Kompilasi model
model.compile(optimizer='adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# 4. Latih model
print("Training Model Dasar (128, 64 neuron)...")
start_time = time.time()
history = model.fit(X_train, y_train, 
                    epochs=10, 
                    batch_size=128, 
                    validation_split=0.1,
                    verbose=1)
training_time = time.time() - start_time

# 5. Evaluasi model
loss, acc = model.evaluate(X_test, y_test, verbose=0)
print(f"\nModel Dasar (128, 64 neuron)")
print(f"Akurasi pada data uji: {acc:.4f}")
print(f"Waktu pelatihan: {training_time:.2f} detik")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Training Model Dasar (128, 64 neuron)...
# Epoch 1/10
# Training Model Dasar (128, 64 neuron)...
# Epoch 1/10
# c:\Users\vidoe\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9024 - loss: 0.3481 - val_accuracy: 0.9593 - val_loss: 0.1536
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9024 - loss: 0.3481 - val_accuracy: 0.9593 - val_loss: 0.1536
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9576 - loss: 0.1446 - val_accuracy: 0.9693 - val_loss: 0.1044
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9576 - loss: 0.1446 - val_accuracy: 0.9693 - val_loss: 0.1044
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9694 - loss: 0.1018 - val_accuracy: 0.9733 - val_loss: 0.0905
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9694 - loss: 0.1018 - val_accuracy: 0.9733 - val_loss: 0.0905
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9761 - loss: 0.0779 - val_accuracy: 0.9722 - val_loss: 0.0919
# Epoch 5/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9761 - loss: 0.0779 - val_accuracy: 0.9722 - val_loss: 0.0919
# Epoch 5/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9812 - loss: 0.0614 - val_accuracy: 0.9758 - val_loss: 0.0799
# Epoch 6/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9812 - loss: 0.0614 - val_accuracy: 0.9758 - val_loss: 0.0799
# Epoch 6/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9842 - loss: 0.0522 - val_accuracy: 0.9780 - val_loss: 0.0811
# Epoch 7/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9842 - loss: 0.0522 - val_accuracy: 0.9780 - val_loss: 0.0811
# Epoch 7/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9875 - loss: 0.0412 - val_accuracy: 0.9768 - val_loss: 0.0779
# Epoch 8/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9875 - loss: 0.0412 - val_accuracy: 0.9768 - val_loss: 0.0779
# Epoch 8/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9897 - loss: 0.0334 - val_accuracy: 0.9765 - val_loss: 0.0877
# Epoch 9/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9897 - loss: 0.0334 - val_accuracy: 0.9765 - val_loss: 0.0877
# Epoch 9/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9917 - loss: 0.0274 - val_accuracy: 0.9793 - val_loss: 0.0776
# Epoch 10/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9917 - loss: 0.0274 - val_accuracy: 0.9793 - val_loss: 0.0776
# Epoch 10/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9934 - loss: 0.0227 - val_accuracy: 0.9797 - val_loss: 0.0768
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9934 - loss: 0.0227 - val_accuracy: 0.9797 - val_loss: 0.0768
#
# Model Dasar (128, 64 neuron)
# Akurasi pada data uji: 0.9791
# Waktu pelatihan: 7.33 detik
#
# Model Dasar (128, 64 neuron)
# Akurasi pada data uji: 0.9791
# Waktu pelatihan: 7.33 detik

# %% [markdown]
# ## Eksperimen 1: Ubah Jumlah Neuron (256 dan 128)

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical
import time

# 1. Load dataset MNIST
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Normalisasi data (0-255 → 0-1)
X_train = X_train / 255.0
X_test = X_test / 255.0

# One-hot encoding label
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# 2. Bangun model dengan neuron lebih banyak
model = Sequential([
    Flatten(input_shape=(28, 28)),  
    Dense(256, activation='relu'),   # Hidden layer 1 - lebih banyak neuron
    Dense(128, activation='relu'),   # Hidden layer 2 - lebih banyak neuron
    Dense(10, activation='softmax')  
])

# 3. Kompilasi model
model.compile(optimizer='adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# 4. Latih model
print("Training Model dengan 256 dan 128 neuron...")
start_time = time.time()
history = model.fit(X_train, y_train, 
                    epochs=10, 
                    batch_size=128, 
                    validation_split=0.1,
                    verbose=1)
training_time = time.time() - start_time

# 5. Evaluasi model
loss, acc = model.evaluate(X_test, y_test, verbose=0)
print(f"\nModel dengan 256 dan 128 neuron")
print(f"Akurasi pada data uji: {acc:.4f}")
print(f"Waktu pelatihan: {training_time:.2f} detik")
# Out:
# Training Model dengan 256 dan 128 neuron...
# Epoch 1/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9171 - loss: 0.2872 - val_accuracy: 0.9605 - val_loss: 0.1356
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9171 - loss: 0.2872 - val_accuracy: 0.9605 - val_loss: 0.1356
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9674 - loss: 0.1094 - val_accuracy: 0.9700 - val_loss: 0.0992
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9674 - loss: 0.1094 - val_accuracy: 0.9700 - val_loss: 0.0992
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9789 - loss: 0.0701 - val_accuracy: 0.9735 - val_loss: 0.0919
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9789 - loss: 0.0701 - val_accuracy: 0.9735 - val_loss: 0.0919
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9835 - loss: 0.0512 - val_accuracy: 0.9778 - val_loss: 0.0707
# Epoch 5/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9835 - loss: 0.0512 - val_accuracy: 0.9778 - val_loss: 0.0707
# Epoch 5/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9883 - loss: 0.0375 - val_accuracy: 0.9783 - val_loss: 0.0757
# Epoch 6/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9883 - loss: 0.0375 - val_accuracy: 0.9783 - val_loss: 0.0757
# Epoch 6/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9910 - loss: 0.0289 - val_accuracy: 0.9788 - val_loss: 0.0740
# Epoch 7/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9910 - loss: 0.0289 - val_accuracy: 0.9788 - val_loss: 0.0740
# Epoch 7/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9936 - loss: 0.0204 - val_accuracy: 0.9820 - val_loss: 0.0719
# Epoch 8/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9936 - loss: 0.0204 - val_accuracy: 0.9820 - val_loss: 0.0719
# Epoch 8/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9949 - loss: 0.0169 - val_accuracy: 0.9793 - val_loss: 0.0823
# Epoch 9/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9949 - loss: 0.0169 - val_accuracy: 0.9793 - val_loss: 0.0823
# Epoch 9/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9958 - loss: 0.0138 - val_accuracy: 0.9808 - val_loss: 0.0766
# Epoch 10/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9958 - loss: 0.0138 - val_accuracy: 0.9808 - val_loss: 0.0766
# Epoch 10/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9954 - loss: 0.0145 - val_accuracy: 0.9772 - val_loss: 0.1026
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9954 - loss: 0.0145 - val_accuracy: 0.9772 - val_loss: 0.1026
#
# Model dengan 256 dan 128 neuron
# Akurasi pada data uji: 0.9735
# Waktu pelatihan: 8.21 detik
#
# Model dengan 256 dan 128 neuron
# Akurasi pada data uji: 0.9735
# Waktu pelatihan: 8.21 detik

# %% [markdown]
# ## Eksperimen 2: Tambah 1 Hidden Layer (3 Hidden Layers)

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical
import time

# 1. Load dataset MNIST
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Normalisasi data (0-255 → 0-1)
X_train = X_train / 255.0
X_test = X_test / 255.0

# One-hot encoding label
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# 2. Bangun model dengan 3 hidden layers
model = Sequential([
    Flatten(input_shape=(28, 28)),  
    Dense(256, activation='relu'),   # Hidden layer 1
    Dense(128, activation='relu'),   # Hidden layer 2
    Dense(64, activation='relu'),    # Hidden layer 3 - layer tambahan
    Dense(10, activation='softmax')  
])

# 3. Kompilasi model
model.compile(optimizer='adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# 4. Latih model
print("Training Model dengan 3 Hidden Layers (256, 128, 64)...")
start_time = time.time()
history = model.fit(X_train, y_train, 
                    epochs=10, 
                    batch_size=128, 
                    validation_split=0.1,
                    verbose=1)
training_time = time.time() - start_time

# 5. Evaluasi model
loss, acc = model.evaluate(X_test, y_test, verbose=0)
print(f"\nModel dengan 3 Hidden Layers (256, 128, 64)")
print(f"Akurasi pada data uji: {acc:.4f}")
print(f"Waktu pelatihan: {training_time:.2f} detik")
# Out:
# Training Model dengan 3 Hidden Layers (256, 128, 64)...
# Epoch 1/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9101 - loss: 0.3054 - val_accuracy: 0.9662 - val_loss: 0.1094
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9101 - loss: 0.3054 - val_accuracy: 0.9662 - val_loss: 0.1094
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9674 - loss: 0.1087 - val_accuracy: 0.9755 - val_loss: 0.0817
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9674 - loss: 0.1087 - val_accuracy: 0.9755 - val_loss: 0.0817
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9788 - loss: 0.0703 - val_accuracy: 0.9773 - val_loss: 0.0830
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9788 - loss: 0.0703 - val_accuracy: 0.9773 - val_loss: 0.0830
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9841 - loss: 0.0512 - val_accuracy: 0.9763 - val_loss: 0.0783
# Epoch 5/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9841 - loss: 0.0512 - val_accuracy: 0.9763 - val_loss: 0.0783
# Epoch 5/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9878 - loss: 0.0389 - val_accuracy: 0.9805 - val_loss: 0.0738
# Epoch 6/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9878 - loss: 0.0389 - val_accuracy: 0.9805 - val_loss: 0.0738
# Epoch 6/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9906 - loss: 0.0293 - val_accuracy: 0.9818 - val_loss: 0.0744
# Epoch 7/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9906 - loss: 0.0293 - val_accuracy: 0.9818 - val_loss: 0.0744
# Epoch 7/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9915 - loss: 0.0248 - val_accuracy: 0.9755 - val_loss: 0.0915
# Epoch 8/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9915 - loss: 0.0248 - val_accuracy: 0.9755 - val_loss: 0.0915
# Epoch 8/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9929 - loss: 0.0213 - val_accuracy: 0.9753 - val_loss: 0.1022
# Epoch 9/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9929 - loss: 0.0213 - val_accuracy: 0.9753 - val_loss: 0.1022
# Epoch 9/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9940 - loss: 0.0175 - val_accuracy: 0.9800 - val_loss: 0.0868
# Epoch 10/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9940 - loss: 0.0175 - val_accuracy: 0.9800 - val_loss: 0.0868
# Epoch 10/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9939 - loss: 0.0178 - val_accuracy: 0.9768 - val_loss: 0.1035
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9939 - loss: 0.0178 - val_accuracy: 0.9768 - val_loss: 0.1035
#
# Model dengan 3 Hidden Layers (256, 128, 64)
# Akurasi pada data uji: 0.9776
# Waktu pelatihan: 8.92 detik
#
# Model dengan 3 Hidden Layers (256, 128, 64)
# Akurasi pada data uji: 0.9776
# Waktu pelatihan: 8.92 detik

# %% [markdown]
# ## Eksperimen 3: Sigmoid vs ReLU

# %% [markdown]
# ### Model dengan Aktivasi Sigmoid

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical
import time

# 1. Load dataset MNIST
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Normalisasi data (0-255 → 0-1)
X_train = X_train / 255.0
X_test = X_test / 255.0

# One-hot encoding label
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# 2. Bangun model dengan aktivasi Sigmoid
model = Sequential([
    Flatten(input_shape=(28, 28)),  
    Dense(128, activation='sigmoid'),   # Hidden layer 1 - Sigmoid
    Dense(64, activation='sigmoid'),    # Hidden layer 2 - Sigmoid
    Dense(10, activation='softmax')  
])

# 3. Kompilasi model
model.compile(optimizer='adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# 4. Latih model
print("Training Model dengan Aktivasi Sigmoid...")
start_time = time.time()
history = model.fit(X_train, y_train, 
                    epochs=10, 
                    batch_size=128, 
                    validation_split=0.1,
                    verbose=1)
training_time = time.time() - start_time

# 5. Evaluasi model
loss, acc = model.evaluate(X_test, y_test, verbose=0)
print(f"\nModel dengan Aktivasi Sigmoid")
print(f"Akurasi pada data uji: {acc:.4f}")
print(f"Loss pada data uji: {loss:.4f}")
print(f"Waktu pelatihan: {training_time:.2f} detik")
# Out:
# Training Model dengan Aktivasi Sigmoid...
# Epoch 1/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8049 - loss: 0.8407 - val_accuracy: 0.9243 - val_loss: 0.3006
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8049 - loss: 0.8407 - val_accuracy: 0.9243 - val_loss: 0.3006
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9187 - loss: 0.2908 - val_accuracy: 0.9422 - val_loss: 0.2010
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9187 - loss: 0.2908 - val_accuracy: 0.9422 - val_loss: 0.2010
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9369 - loss: 0.2172 - val_accuracy: 0.9555 - val_loss: 0.1652
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9369 - loss: 0.2172 - val_accuracy: 0.9555 - val_loss: 0.1652
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9500 - loss: 0.1735 - val_accuracy: 0.9633 - val_loss: 0.1333
# Epoch 5/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9500 - loss: 0.1735 - val_accuracy: 0.9633 - val_loss: 0.1333
# Epoch 5/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9587 - loss: 0.1428 - val_accuracy: 0.9687 - val_loss: 0.1150
# Epoch 6/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9587 - loss: 0.1428 - val_accuracy: 0.9687 - val_loss: 0.1150
# Epoch 6/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9655 - loss: 0.1193 - val_accuracy: 0.9697 - val_loss: 0.1026
# Epoch 7/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9655 - loss: 0.1193 - val_accuracy: 0.9697 - val_loss: 0.1026
# Epoch 7/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9711 - loss: 0.1009 - val_accuracy: 0.9732 - val_loss: 0.0943
# Epoch 8/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9711 - loss: 0.1009 - val_accuracy: 0.9732 - val_loss: 0.0943
# Epoch 8/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9759 - loss: 0.0861 - val_accuracy: 0.9743 - val_loss: 0.0864
# Epoch 9/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9759 - loss: 0.0861 - val_accuracy: 0.9743 - val_loss: 0.0864
# Epoch 9/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9794 - loss: 0.0743 - val_accuracy: 0.9740 - val_loss: 0.0836
# Epoch 10/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9794 - loss: 0.0743 - val_accuracy: 0.9740 - val_loss: 0.0836
# Epoch 10/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9824 - loss: 0.0639 - val_accuracy: 0.9765 - val_loss: 0.0770
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9824 - loss: 0.0639 - val_accuracy: 0.9765 - val_loss: 0.0770
#
# Model dengan Aktivasi Sigmoid
# Akurasi pada data uji: 0.9733
# Loss pada data uji: 0.0864
# Waktu pelatihan: 7.42 detik
#
# Model dengan Aktivasi Sigmoid
# Akurasi pada data uji: 0.9733
# Loss pada data uji: 0.0864
# Waktu pelatihan: 7.42 detik

# %% [markdown]
# ### Model dengan Aktivasi ReLU

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical
import time

# 1. Load dataset MNIST
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Normalisasi data (0-255 → 0-1)
X_train = X_train / 255.0
X_test = X_test / 255.0

# One-hot encoding label
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# 2. Bangun model dengan aktivasi ReLU
model = Sequential([
    Flatten(input_shape=(28, 28)),  
    Dense(128, activation='relu'),   # Hidden layer 1 - ReLU
    Dense(64, activation='relu'),    # Hidden layer 2 - ReLU
    Dense(10, activation='softmax')  
])

# 3. Kompilasi model
model.compile(optimizer='adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# 4. Latih model
print("Training Model dengan Aktivasi ReLU...")
start_time = time.time()
history = model.fit(X_train, y_train, 
                    epochs=10, 
                    batch_size=128, 
                    validation_split=0.1,
                    verbose=1)
training_time = time.time() - start_time

# 5. Evaluasi model
loss, acc = model.evaluate(X_test, y_test, verbose=0)
print(f"\nModel dengan Aktivasi ReLU")
print(f"Akurasi pada data uji: {acc:.4f}")
print(f"Loss pada data uji: {loss:.4f}")
print(f"Waktu pelatihan: {training_time:.2f} detik")
# Out:
# Training Model dengan Aktivasi ReLU...
# Epoch 1/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9000 - loss: 0.3533 - val_accuracy: 0.9583 - val_loss: 0.1463
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9000 - loss: 0.3533 - val_accuracy: 0.9583 - val_loss: 0.1463
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9578 - loss: 0.1428 - val_accuracy: 0.9730 - val_loss: 0.0991
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9578 - loss: 0.1428 - val_accuracy: 0.9730 - val_loss: 0.0991
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9712 - loss: 0.0962 - val_accuracy: 0.9747 - val_loss: 0.0886
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9712 - loss: 0.0962 - val_accuracy: 0.9747 - val_loss: 0.0886
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9779 - loss: 0.0726 - val_accuracy: 0.9765 - val_loss: 0.0780
# Epoch 5/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9779 - loss: 0.0726 - val_accuracy: 0.9765 - val_loss: 0.0780
# Epoch 5/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9833 - loss: 0.0570 - val_accuracy: 0.9785 - val_loss: 0.0749
# Epoch 6/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9833 - loss: 0.0570 - val_accuracy: 0.9785 - val_loss: 0.0749
# Epoch 6/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9851 - loss: 0.0472 - val_accuracy: 0.9773 - val_loss: 0.0757
# Epoch 7/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9851 - loss: 0.0472 - val_accuracy: 0.9773 - val_loss: 0.0757
# Epoch 7/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9893 - loss: 0.0362 - val_accuracy: 0.9785 - val_loss: 0.0778
# Epoch 8/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9893 - loss: 0.0362 - val_accuracy: 0.9785 - val_loss: 0.0778
# Epoch 8/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9907 - loss: 0.0309 - val_accuracy: 0.9800 - val_loss: 0.0742
# Epoch 9/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9907 - loss: 0.0309 - val_accuracy: 0.9800 - val_loss: 0.0742
# Epoch 9/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9924 - loss: 0.0251 - val_accuracy: 0.9765 - val_loss: 0.0856
# Epoch 10/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9924 - loss: 0.0251 - val_accuracy: 0.9765 - val_loss: 0.0856
# Epoch 10/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9937 - loss: 0.0209 - val_accuracy: 0.9767 - val_loss: 0.0899
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9937 - loss: 0.0209 - val_accuracy: 0.9767 - val_loss: 0.0899
#
# Model dengan Aktivasi ReLU
# Akurasi pada data uji: 0.9751
# Loss pada data uji: 0.0867
# Waktu pelatihan: 7.24 detik
#
# Model dengan Aktivasi ReLU
# Akurasi pada data uji: 0.9751
# Loss pada data uji: 0.0867
# Waktu pelatihan: 7.24 detik

# %% [markdown]
# ## Rangkuman Hasil Eksperimen
#
# Jalankan semua sel di atas untuk mendapatkan perbandingan lengkap.
#
# ### Hasil yang Diharapkan:
#
# #### 1. Perbandingan Jumlah Neuron:
# - **Model Dasar (128, 64)**: Baseline untuk perbandingan
# - **Model Lebih Besar (256, 128)**:
#   - ✓ Akurasi cenderung lebih tinggi
#   - ✗ Waktu training lebih lama
#   - ✗ Lebih banyak parameter (risiko overfitting)
#
# #### 2. Perbandingan Jumlah Hidden Layer:
# - **2 Hidden Layers**: Model sederhana dan cepat
# - **3 Hidden Layers (256, 128, 64)**:
#   - ✓ Dapat menangkap pola lebih kompleks
#   - ✓ Akurasi potensial lebih tinggi
#   - ✗ Training lebih lambat
#   - ✗ Risiko overfitting meningkat
#
# #### 3. Perbandingan Fungsi Aktivasi:
# - **Sigmoid**:
#   - ✗ Masalah vanishing gradient
#   - ✗ Akurasi lebih rendah
#   - ✗ Konvergensi lebih lambat
#   - Output terbatas 0-1
#
# - **ReLU**:
#   - ✓ Mengatasi vanishing gradient
#   - ✓ Akurasi lebih tinggi
#   - ✓ Training lebih cepat
#   - ✓ Konvergensi lebih baik
